# %%
import pandas as pd
from datetime import date
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
def read_archive(path_arquivo):
    lines = [] 
    with open(path_arquivo) as arquivo:
        for line in arquivo:
            lines.append(line.split())
    df = pd.DataFrame(lines, columns= ['DIA', 'MES', 'ANO', 'MEDICAO'])
    return df

def dados(dado):
    ano = dado['ANO']
    mes = dado['MES']
    dia = dado['DIA']
    medidas = {"DATA":[], "MEDICAO":[]}
    for med in range(len(dado['ANO'])):
        if float(dado['MEDICAO'][med]) > 0:
            d = int(dia[med])
            m = int(mes[med])
            medidas['DATA'].append(date(int(ano[med]), m, d))
            medidas['MEDICAO'].append(float(dado['MEDICAO'][med]))
    return medidas

# converte um pandas dataframe no input apropriado para o LSTM
def datasetLSTM(dataset, quantidade): # df, range da data
    df = []
    param1 = 0
    param2 = 0
    for i in range(len(dataset)):
        lista=[]
        try:
            lista.append(dataset[i])
            for j in range (quantidade):
                lista.append(dataset[i+j+1])
                param1 = i
                param2 = j
            lista.append(dataset[param1+param2+15])
            param1=0
            param2=0            
            df.append(lista)
        except:
            print(f"erro no indexador {i}/{len(dataset)}")
    return df

# %%
# %cd ..

df = read_archive("15700000.txt")
df = pd.DataFrame(dados(df))
# Out:
# /home/fernandoarkade/Documents/IA_rioMadeira/VisualizacaoDeDadosRioMadeira

# %%
df
# Out:
#             DATA  MEDICAO
# 0     2001-01-01   1803.0
# 1     2001-01-02   1794.0
# 2     2001-01-03   1799.0
# 3     2001-01-04   1808.0
# 4     2001-01-05   1818.0
# ...          ...      ...
# 5108  2014-12-27   1982.0
# 5109  2014-12-28   1996.0
# 5110  2014-12-29   2017.0
# 5111  2014-12-30   2042.0
# 5112  2014-12-31   2061.0
#
# [5113 rows x 2 columns]

# %%
# removendo a coluna "DATA" e atribuindo-a a variável date_time
date_time = pd.to_datetime(df.pop('DATA'), format='%Y-%m-%d')
# convertendo em float32
df = df.astype('float32')
# normalizando
scaler = MinMaxScaler(feature_range=(0, 1))
df = scaler.fit_transform(df)

# criando input para o LSTM a partir do dataframe

r = 14 # range de dias 
d= 15 # dias a partir de r + 1


df2 = datasetLSTM(df, r)

# dataset de teste
dfTest = pd.DataFrame(df2)
dfTest = dfTest.astype("float")
colunas = [i for i in range(r+1)] 
colunas.append(str(r+1+d))
dfTest.columns = colunas

dfTest
# Out:
# erro no indexador 5085/5113
# erro no indexador 5086/5113
# erro no indexador 5087/5113
# erro no indexador 5088/5113
# erro no indexador 5089/5113
# erro no indexador 5090/5113
# erro no indexador 5091/5113
# erro no indexador 5092/5113
# erro no indexador 5093/5113
# erro no indexador 5094/5113
# erro no indexador 5095/5113
# erro no indexador 5096/5113
# erro no indexador 5097/5113
# erro no indexador 5098/5113
# erro no indexador 5099/5113
# erro no indexador 5100/5113
# erro no indexador 5101/5113
# erro no indexador 5102/5113
# erro no indexador 5103/5113
# erro no indexador 5104/5113
# erro no indexador 5105/5113
# erro no indexador 5106/5113
# erro no indexador 5107/5113
# erro no indexador 5108/5113
# erro no indexador 5109/5113
# erro no indexador 5110/5113
# erro no indexador 5111/5113
# erro no indexador 5112/5113
#              0         1         2         3         4         5         6  \
# 0     0.388951  0.383878  0.386697  0.391770  0.397407  0.405299  0.414882
# 1     0.383878  0.386697  0.391770  0.397407  0.405299  0.414882  0.421082
# 2     0.386697  0.391770  0.397407  0.405299  0.414882  0.421082  0.427283
# 3     0.391770  0.397407  0.405299  0.414882  0.421082  0.427283  0.435175
# 4     0.397407  0.405299  0.414882  0.421082  0.427283  0.435175  0.440812
# ...        ...       ...       ...       ...       ...       ...       ...
# 5080  0.332018  0.339910  0.347802  0.353439  0.357948  0.362458  0.370913
# 5081  0.339910  0.347802  0.353439  0.357948  0.362458  0.370913  0.385006
# 5082  0.347802  0.353439  0.357948  0.362458  0.370913  0.385006  0.396843
# 5083  0.353439  0.357948  0.362458  0.370913  0.385006  0.396843  0.408681
# 5084  0.357948  0.362458  0.370913  0.385006  0.396843  0.408681  0.420519
#
#              7         8         9        10        11        12        13  \
# 0     0.421082  0.427283  0.435175  0.440812  0.449267  0.458286  0.470124
# 1     0.427283  0.435175  0.440812  0.449267  0.458286  0.470124  0.485907
# 2     0.435175  0.440812  0.449267  0.458286  0.470124  0.485907  0.503382
# 3     0.440812  0.449267  0.458286  0.470124  0.485907  0.503382  0.519729
# 4     0.449267  0.458286  0.470124  0.485907  0.503382  0.519729  0.534386
# ...        ...       ...       ...       ...       ...       ...       ...
# 5080  0.385006  0.396843  0.408681  0.420519  0.428410  0.435175  0.445321
# 5081  0.396843  0.408681  0.420519  0.428410  0.435175  0.445321  0.458850
# 5082  0.408681  0.420519  0.428410  0.435175  0.445321  0.458850  0.463923
# 5083  0.420519  0.428410  0.435175  0.445321  0.458850  0.463923  0.463360
# 5084  0.428410  0.435175  0.445321  0.458850  0.463923  0.463360  0.461105
#
#             14        30
# 0     0.485907  0.636979
# 1     0.503382  0.641488
# 2     0.519729  0.646561
# 3     0.534386  0.652198
# 4     0.551860  0.658963
# ...        ...       ...
# 5080  0.458850  0.489853
# 5081  0.463923  0.497745
# 5082  0.463360  0.509583
# 5083  0.461105  0.523675
# 5084  0.458850  0.534386
#
# [5085 rows x 16 columns]

# %%
# train/ test split
test_size = int(len(dfTest) * 0.2)
test = dfTest.iloc[-test_size::].copy()
train = dfTest.iloc[:-test_size:].copy()


# dropando target
X_train = train.drop("30",axis=1).copy()
y_train = train[["30"]].copy()

# transformando em numpy array
scaled_X_train = X_train.to_numpy()
scaled_y_train = y_train.to_numpy()

# transformando array
scaled_y_train = scaled_y_train.reshape(-1)
scaled_y_train = np.insert(scaled_y_train, 0, 0)
scaled_y_train = np.delete(scaled_y_train, -1)

# entradas do modelo
n_input = 15
n_features= X_train.shape[1]
b_size = 32
generator = TimeseriesGenerator(scaled_X_train, scaled_y_train, length=n_input, batch_size=b_size)

# validação 

y_test = test[["30"]]
scaled_y_test = y_test.to_numpy()
X_test = test.drop("30",axis=1).copy()
scaled_X_test  = X_test.to_numpy()
test_generator = TimeseriesGenerator(scaled_X_test, scaled_y_test, length=n_input, batch_size=b_size)

print(f"generator {generator[0][0].shape}")
# Out:
# generator (32, 15, 15)

# %%
generator[2]
# Out:
# (array([[[0.74746329, 0.75084549, 0.75310034, ..., 0.79368657,
#           0.79819614, 0.80157834],
#          [0.75084549, 0.75310034, 0.75648254, ..., 0.79819614,
#           0.80157834, 0.80496055],
#          [0.75310034, 0.75648254, 0.75873727, ..., 0.80157834,
#           0.80496055, 0.80834264],
#          ...,
#          [0.79368657, 0.79819614, 0.80157834, ..., 0.82187146,
#           0.82412618, 0.82581729],
#          [0.79819614, 0.80157834, 0.80496055, ..., 0.82412618,
#           0.82581729, 0.82638103],
#          [0.80157834, 0.80496055, 0.80834264, ..., 0.82581729,
#           0.82638103, 0.82638103]],
#
#         [[0.75084549, 0.75310034, 0.75648254, ..., 0.79819614,
#           0.80157834, 0.80496055],
#          [0.75310034, 0.75648254, 0.75873727, ..., 0.80157834,
#           0.80496055, 0.80834264],
#          [0.75648254, 0.75873727, 0.76211947, ..., 0.80496055,
#           0.80834264, 0.81003374],
#          ...,
#          [0.79819614, 0.80157834, 0.80496055, ..., 0.82412618,
#           0.82581729, 0.82638103],
#          [0.80157834, 0.80496055, 0.80834264, ..., 0.82581729,
#           0.82638103, 0.82638103],
#          [0.80496055, 0.80834264, 0.81003374, ..., 0.82638103,
#           0.82638103, 0.82694477]],
#
#         [[0.75310034, 0.75648254, 0.75873727, ..., 0.80157834,
#           0.80496055, 0.80834264],
#          [0.75648254, 0.75873727, 0.76211947, ..., 0.80496055,
#           0.80834264, 0.81003374],
#          [0.75873727, 0.76211947, 0.76550168, ..., 0.80834264,
#           0.81003374, 0.81116122],
#          ...,
#          [0.80157834, 0.80496055, 0.80834264, ..., 0.82581729,
#           0.82638103, 0.82638103],
#          [0.80496055, 0.80834264, 0.81003374, ..., 0.82638103,
#           0.82638103, 0.82694477],
#          [0.80834264, 0.81003374, 0.81116122, ..., 0.82638103,
#           0.82694477, 0.82807213]],
#
#         ...,
#
#         [[0.82694477, 0.82807213, 0.82919949, ..., 0.83201796,
#           0.82863575, 0.82525367],
#          [0.82807213, 0.82919949, 0.83032686, ..., 0.82863575,
#           0.82525367, 0.82243508],
#          [0.82919949, 0.83032686, 0.83145434, ..., 0.82525367,
#           0.82243508, 0.82187146],
#          ...,
#          [0.83201796, 0.82863575, 0.82525367, ..., 0.8010146 ,
#           0.79481393, 0.7874859 ],
#          [0.82863575, 0.82525367, 0.82243508, ..., 0.79481393,
#           0.7874859 , 0.78297633],
#          [0.82525367, 0.82243508, 0.82187146, ..., 0.7874859 ,
#           0.78297633, 0.77677566]],
#
#         [[0.82807213, 0.82919949, 0.83032686, ..., 0.82863575,
#           0.82525367, 0.82243508],
#          [0.82919949, 0.83032686, 0.83145434, ..., 0.82525367,
#           0.82243508, 0.82187146],
#          [0.83032686, 0.83145434, 0.8325817 , ..., 0.82243508,
#           0.82187146, 0.82130772],
#          ...,
#          [0.82863575, 0.82525367, 0.82243508, ..., 0.79481393,
#           0.7874859 , 0.78297633],
#          [0.82525367, 0.82243508, 0.82187146, ..., 0.7874859 ,
#           0.78297633, 0.77677566],
#          [0.82243508, 0.82187146, 0.82130772, ..., 0.78297633,
#           0.77677566, 0.77170235]],
#
#         [[0.82919949, 0.83032686, 0.83145434, ..., 0.82525367,
#           0.82243508, 0.82187146],
#          [0.83032686, 0.83145434, 0.8325817 , ..., 0.82243508,
#           0.82187146, 0.82130772],
#          [0.83145434, 0.8325817 , 0.83370906, ..., 0.82187146,
#           0.82130772, 0.81736189],
#          ...,
#          [0.82525367, 0.82243508, 0.82187146, ..., 0.7874859 ,
#           0.78297633, 0.77677566],
#          [0.82243508, 0.82187146, 0.82130772, ..., 0.78297633,
#           0.77677566, 0.77170235],
#          [0.82187146, 0.82130772, 0.81736189, ..., 0.77677566,
#           0.77170235, 0.7643742 ]]]),
#  array([0.82863575, 0.82525367, 0.82243508, 0.82187146, 0.82130772,
#         0.81736189, 0.81454331, 0.81003374, 0.80777901, 0.80439681,
#         0.80214196, 0.8010146 , 0.79481393, 0.7874859 , 0.78297633,
#         0.77677566, 0.77170235, 0.7643742 , 0.75648254, 0.75140923,
#         0.74746329, 0.74520856, 0.74295372, 0.73900789, 0.73449832,
#         0.72886127, 0.7243517 , 0.7192784 , 0.71758729, 0.71702367,
#         0.71702367, 0.71533257]))

# %%
basemodel = Sequential()
basemodel.add(LSTM(150, activation='relu', input_shape=(n_input, n_features)))
basemodel.add(Dense(1, activation='sigmoid'))
optimizer = Adam(lr=0.001)
basemodel.compile(optimizer=optimizer, loss='mse')
basemodel.summary()
# Out:
# Model: "sequential_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_56 (LSTM)              (None, 150)               99600
#
#  dense_105 (Dense)           (None, 1)                 151
#
# =================================================================
# Total params: 99,751
# Trainable params: 99,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.metrics import r2_score

# baseado nos parametros do modelo base
param_grid = {'units': [50, 100, 150],
              'dropout': [0.2, 0.3, 0.4],
              'optimizer': ['adam', 'rmsprop']
             }
def create_model(units=150, dropout=0.2, optimizer= Adam(lr=0.001), n_input= 15, n_features= 15):
    model = Sequential()
    model.add(LSTM(units, activation = 'relu', input_shape=(n_inputs, n_features)))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# quantas vezes o modelo vai rodar até convergir
epocas = 30

#batch size, quantidade de exemplos em cada iteração
ex = generator.batch_size

# criar o modelo usando KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=epocas, batch_size=32, verbose=0)

folds = 3
# realizar o grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=folds)


#X_train = np.reshape(generator.data, (0, 15, generator.data.shape[1]))
#y_train = np.reshape(generator.targets, (generator.targets.shape[0], generator.targets.shape[1], 1))

grid_result = grid.fit(X_train, generator.targets)

# Avaliar os modelos

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# /tmp/ipykernel_6886/2041176144.py:25: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=epocas, batch_size=32, verbose=0)
# Best: -0.002472 using {'dropout': 0.2, 'optimizer': 'adam', 'units': 150}
# -0.002811 (0.000333) with: {'dropout': 0.2, 'optimizer': 'adam', 'units': 50}
# -0.002606 (0.000335) with: {'dropout': 0.2, 'optimizer': 'adam', 'units': 100}
# -0.002472 (0.000351) with: {'dropout': 0.2, 'optimizer': 'adam', 'units': 150}
# -0.002972 (0.000724) with: {'dropout': 0.2, 'optimizer': 'rmsprop', 'units': 50}
# -0.002629 (0.000349) with: {'dropout': 0.2, 'optimizer': 'rmsprop', 'units': 100}
# -0.002720 (0.000419) with: {'dropout': 0.2, 'optimizer': 'rmsprop', 'units': 150}
# -0.003611 (0.000236) with: {'dropout': 0.3, 'optimizer': 'adam', 'units': 50}
# -0.002794 (0.000269) with: {'dropout': 0.3, 'optimizer': 'adam', 'units': 100}
# -0.002655 (0.000339) with: {'dropout': 0.3, 'optimizer': 'adam', 'units': 150}
# -0.003057 (0.000535) with: {'dropout': 0.3, 'optimizer': 'rmsprop', 'units': 50}
# -0.003713 (0.001157) with: {'dropout': 0.3, 'optimizer': 'rmsprop', 'units': 100}
# -0.002638 (0.000363) with: {'dropout': 0.3, 'optimizer': 'rmsprop', 'units': 150}
# -0.003484 (0.000620) with: {'dropout': 0.4, 'optimizer': 'adam', 'units': 50}
# -0.002859 (0.000230) with: {'dropout': 0.4, 'optimizer': 'adam', 'units': 100}
# -0.003025 (0.000272) with: {'dropout': 0.4, 'optimizer': 'adam', 'units': 150}
# -0.003350 (0.000639) with: {'dropout': 0.4, 'optimizer': 'rmsprop', 'units': 50}
# -0.003307 (0.000744) with: {'dropout': 0.4, 'optimizer': 'rmsprop', 'units': 100}
# -0.002767 (0.000631) with: {'dropout': 0.4, 'optimizer': 'rmsprop', 'units': 150}

# %%
generator.data
# Out:
# array([0.38669676, 0.39176995, 0.397407  , 0.40529877, 0.41488165,
#        0.42108232, 0.42728299, 0.43517476, 0.44081169, 0.44926721,
#        0.45828635, 0.47012395, 0.4859075 , 0.50338215, 0.51972944])

# %%
len(generator.data.shape)
# Out:
# 2

# %%
model.fit_generator(generator,epochs=150)
# Out:
# Epoch 1/150
# /tmp/ipykernel_16641/1404262375.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator,epochs=150)
# 2023-04-18 23:02:32.548387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0497
# Epoch 2/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0159
# Epoch 3/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0112
# Epoch 4/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0093
# Epoch 5/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0063
# Epoch 6/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0068
# Epoch 7/150
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0083
# Epoch 8/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0054
# Epoch 9/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 10/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 11/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0048
# Epoch 12/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0048
# Epoch 13/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0045
# Epoch 14/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0049
# Epoch 15/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 16/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0044
# Epoch 17/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 18/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0042
# Epoch 19/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0040
# Epoch 20/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0056
# Epoch 21/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0038
# Epoch 22/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0045
# Epoch 23/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0043
# Epoch 24/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0044
# Epoch 25/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0041
# Epoch 26/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0036
# Epoch 27/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0031
# Epoch 28/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0040
# Epoch 29/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0035
# Epoch 30/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 31/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 32/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0038
# Epoch 33/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0035
# Epoch 34/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0035
# Epoch 35/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0043
# Epoch 36/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0031
# Epoch 37/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0037
# Epoch 38/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0032
# Epoch 39/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0028
# Epoch 40/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 41/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0032
# Epoch 42/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0032
# Epoch 43/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0034
# Epoch 44/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 45/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0033
# Epoch 46/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0029
# Epoch 47/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 48/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0030
# Epoch 49/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 50/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0029
# Epoch 51/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0027
# Epoch 52/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0028
# Epoch 53/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 54/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0027
# Epoch 55/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0026
# Epoch 56/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0031
# Epoch 57/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0028
# Epoch 58/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0030
# Epoch 59/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0026
# Epoch 60/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0026
# Epoch 61/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 62/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 63/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 64/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0028
# Epoch 65/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 66/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 67/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 68/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 69/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0023
# Epoch 70/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 71/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0029
# Epoch 72/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 73/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 74/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 75/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0026
# Epoch 76/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0022
# Epoch 77/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 78/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0029
# Epoch 79/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 80/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 81/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0022
# Epoch 82/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 83/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 84/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0025
# Epoch 85/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0026
# Epoch 86/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 87/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 88/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 89/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 90/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 91/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 92/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 93/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 94/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0024
# Epoch 95/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 96/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 97/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 98/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 99/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 100/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 101/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 102/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 103/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 104/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 105/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 106/150
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0023
# Epoch 107/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 108/150
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 109/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 110/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 111/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 112/150
# 127/127 [==============================] - 1s 5ms/step - loss: 0.0019
# Epoch 113/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 114/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 115/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 116/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0023
# Epoch 117/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 118/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 119/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0018
# Epoch 120/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 121/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 122/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 123/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 124/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 125/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 126/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0017
# Epoch 127/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0016
# Epoch 128/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 129/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0017
# Epoch 130/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 131/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0017
# Epoch 132/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 133/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0022
# Epoch 134/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 135/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0019
# Epoch 136/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0020
# Epoch 137/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 138/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 139/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0021
# Epoch 140/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0016
# Epoch 141/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0024
# Epoch 142/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 143/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0016
# Epoch 144/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 145/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0016
# Epoch 146/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 147/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0016
# Epoch 148/150
# 127/127 [==============================] - 1s 6ms/step - loss: 0.0018
# Epoch 149/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0019
# Epoch 150/150
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0017

# %%
loss_per_epoch = model.history.history['loss']
plt.figure(figsize=(16,9))
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
!

# %%
y_test = test[["30"]]
scaled_y_test = y_test.to_numpy()
scaled_y_test
# Out:
# array([[0.80496055],
#        [0.80439681],
#        [0.80439681],
#        ...,
#        [0.50958282],
#        [0.52367526],
#        [0.5343855 ]])

# %%
X_test = test.drop("30",axis=1).copy()
scaled_X_test  = X_test.to_numpy()
test_generator = TimeseriesGenerator(scaled_X_test, scaled_y_test, length=n_input, batch_size=b_size)

# %%
y_pred_scaled = model.predict(test_generator)
# Out:
# 19/32 [================>.............] - ETA: 0s
# 2023-04-18 23:04:41.879377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 32/32 [==============================] - 0s 3ms/step

# %%
results = pd.DataFrame({'Dados Reais':test["30"].values[n_input:],'Dados Previstos':y_pred_scaled.ravel()})

# %%
results.plot(title="Gráfico de comparação dados reais x previstos", figsize=(16,9))
# Out:
# <AxesSubplot:title={'center':'Gráfico de comparação dados reais x previstos'}>

# %% [markdown]
# # Métricas

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
mse = tf.keras.losses.MeanSquaredError()
print("Mean Squared Error: " + str(mse(test["30"].values[n_input:], y_pred_scaled).numpy()))
rmse = tf.keras.metrics.RootMeanSquaredError()
print("Root Mean Squared Error: " + str(rmse(test["30"].values[n_input:], y_pred_scaled).numpy()))
mae = tf.keras.losses.MeanAbsoluteError()
print("Mean Absolute Error: " + str(mae(test["30"].values[n_input:], y_pred_scaled).numpy()))

r2 = r2_score(test["30"].values[n_input:], y_pred_scaled)
print("R-Squared metric: "+ str(r2))
# Out:
# Mean Squared Error: 0.13498218
# Root Mean Squared Error: 0.062034007
# Mean Absolute Error: 0.29948196
# R-Squared metric: 0.9445715419087739
